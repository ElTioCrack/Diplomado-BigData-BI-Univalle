# %% [markdown]
# <img src=./../figuras/python3.jpg align=left><BR><BR><BR><BR><BR><BR>
# <h1>Programación Orientada a Objetos (POO)</h1>
# <img src=./../figuras/python-logo.png align=left>

# %% [markdown]
# # 7.1 Introducción
#
# Los objetos son una manera de organizar datos y de relacionar esos datos con el código apropieado para manejarlo. Son los protagonistas de un paradigma de progrmación llamado Progrmación Orientada a Objetos.
#
# Nosotros ya usamos objetos en Python sin mencionarlo explícitamente. Es más, todos los tipos de datos que Python nos provee son, en realidad, objetos.
#
# De forma que, cuando utilizamos miarchivo.readline(), le estamos diciendo a Python que llame a la función readline del tipo file para miarchivo que es lo mismo que decir que llame al método readline del objeto miarchivo.
#
# A su vez, a las variables que un objeto contiene, se las llama atributos.
#
# ---
#
# ## 7.1.1 Tipos
#
# En los temas que vimos hasta ahora nos hemos encontrado con numerosos tipos provistos por Python, los números, las cadenas de caracteres, las listas, las tuplas, los diccionarios, los archivos, etc. Cada uno de estos tipos tiene sus características, tienen operaciones propias de cada uno y nos proveen una gran cantidad de funcionalidades que podemos utilizar para nuestros programas.
#
# Como ya se dijo anteriormente, para saber de qué tipo es una variable, utilizamos la función type, y para saber qué métodos y atributos tiene esa variable utilizamos la función dir.

# %%
a = open("./3.1.2/test.txt")
print(type(a))
print(a.readlines())
# Out:
# <class '_io.TextIOWrapper'>
# ['Line 0\n', 'Line 1\n', 'Line 2\n', 'Line 3\n', 'Line 4\n', 'Line 5\n', 'Line 6\n', 'Line 7\n', 'Line 8\n', 'Line 9\n']

# %%
dir(a)
# Out:
# ['_CHUNK_SIZE',
#  '__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_checkClosed',
#  '_checkReadable',
#  '_checkSeekable',
#  '_checkWritable',
#  '_finalizing',
#  'buffer',
#  'close',
#  'closed',
#  'detach',
#  'encoding',
#  'errors',
#  'fileno',
#  'flush',
#  'isatty',
#  'line_buffering',
#  'mode',
#  'name',
#  'newlines',
#  'read',
#  'readable',
#  'readline',
#  'readlines',
#  'reconfigure',
#  'seek',
#  'seekable',
#  'tell',
#  'truncate',
#  'writable',
#  'write',
#  'write_through',
#  'writelines']

# %% [markdown]
# En este caso, la función dir nos muestra los métodos que tiene un objeto del tipo file. Podemos ver en el listado los métodos que ya hemos visto al operar con archivos, junto con otros métodos con nombres raros como __str__ o __doc__, estos métodos son especiales en Python, más adelante veremos para qué sirven y cómo se usan.

# %% [markdown]
# En el listado que nos da dir están los atributos y métodos mezclados. Si necesitamos saber cuáles son atributos y cuáles son métodos, podemos hacerlo nuevamente mediante el uso de type.

# %%
type (a.name)
print(type(a.name))
print(type(a.readlines))
# Out:
# <class 'str'>
# <class 'builtin_function_or_method'>

# %%
a.name
# Out:
# './3.1.2/test.txt'

# %%
type (a.tell)
# Out:
# builtin_function_or_method

# %%
a.tell()
# Out:
# 80

# %%
x = 'abc'
type(x)
# Out:
# str

# %%
dir(x)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
y = list()

# %%
dir(y)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
z = dict()

# %%
dir(z)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
class PartyAnimal:
    x = 0
    def party(self) :
        self.x = self.x + 1
        print("So far",self.x)

an = PartyAnimal()

an.party()
an.party()
an.party()
# Out:
# So far 1
# So far 2
# So far 3

# %%
dir(an)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'party',
#  'x']

# %%
dir(PartyAnimal)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'party',
#  'x']

# %%
class PartyAnimal:
    x = 0
    def __init__(self):
        print('Soy un contructor')
    def party(self) :
        self.x = self.x + 1
        print("So far",self.x)
    def __del__(self):
        print('Soy un destructor', self.x)

an = PartyAnimal()

an.party()
an.party()
print('an contiene', an)
an = 42      ## estoy referencia que an = 42 (entero) y esta perdiendo su refencia a la clase PartyAnimal
print('an contiene', an)
# Out:
# Soy un contructor
# So far 1
# So far 2
# an contiene <__main__.PartyAnimal object at 0x000002CC45AB9BE0>
# Soy un destructor 2
# an contiene 42

# %%
an.party()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 an.party()
#
# AttributeError: 'int' object has no attribute 'party'

# %%
class PartyAnimal:
    x = 0
    name = ""
    def __init__(self, z):
        self.name = z
        print('Soy un contructor')
    def party(self) :
        self.x = self.x + 1
        print("So far",self.x)
    def __del__(self):
        print('Soy un destructor', self.x)

s = PartyAnimal("Sally")
j = PartyAnimal("Jim")
# Out:
# Soy un contructor
# Soy un contructor

# %%
s.party()
# Out:
# So far 1

# %%
j.party()
s.party()
# Out:
# So far 1
# So far 2

# %%
s,j = 0,0
# Out:
# Soy un destructor 2
# Soy un destructor 1

# %%
class PartyAnimal:
    x = 0
    name = ""
    def __init__(self, nam):
        self.name = nam
        print('Soy un contructor')
    def party(self) :
        self.x = self.x + 1
        print("So far",self.x)
    def __del__(self):
        print('Soy un destructor', self.x)

# Clase FootballFan heredada de PartyAnimal
class FootballFan(PartyAnimal):
    points = 0
    def touchdown(self):
        self.points = self.points + 7
        self.party()
        print(self.name, "points", self.points)
        print(f"La fiesta de {self.name} tiene {self.x} participantes y consiguieron un touchdown: {self.points}")

s = PartyAnimal("Sally")
s.party()

j = FootballFan("Jim")
j.party()
j.touchdown()
# Out:
# Soy un contructor
# So far 1
# Soy un contructor
# So far 1
# So far 2
# Jim points 7
# La fiesta de Jim tiene 2 participantes y consiguieron un touchdown: 7

# %%
j.touchdown()
# Out:
# So far 3
# Jim points 14
# La fiesta de Jim tiene 3 participantes y consiguieron un touchdown: 14

# %% [markdown]
# Es decir que name es un atributo del objeto (el nombre del archivo), mientras que tell es un método, que para utilizarlo debemos llamarlo con paréntesis.
#
# <b>Nota:</b>
#
# Como ya sabemos, en Python, los métodos se invocan con la notación punto: archivo.tell(), cadena.split(":").
#
# Analicemos la segunda expresión. El significado de ésta es: la variable cadena, llama al método split (del cual es dueña por tratarse de una variable de tipo str) con el argumento ":".
#
# Sería equivalente a llamar a la función split pasándole como primer parámetro la variable, y como segundo parámetro el delimitador. Pero la diferencia de notación resalta que el método split es un método de cadenas, y que no se lo puede utilizar con variables de otros tipos.
#
# Esta notación provocó un cambio de paradigma en la programación, y es uno de los ejes de la Programación Orientada a Objetos.
#
# ---
#
# ## 7.1.2 Objetos
#
# En Python, todos los tipos son objetos. Pero no en todos los lenguajes de programación es así. En general, podemos decir que un objeto es una forma ordenada de agrupar datos (los atributos) y operaciones a utilizar sobre esos datos (los métodos).
#
# Es importante notar que cuando decimos objetos podemos estar haciendo referencia a dos cosas parecidas, pero distintas.
#
# Por un lado, la definición del tipo, donde se indican cuáles son los atributos y métodos que van a tener todas las variables que sean de ese tipo. Esta definición se llama específicamente, <b>la clase del objeto</b>.
#
# A partir de una clase es posible crear distintas variables que son de ese tipo. A las variables que son de una clase en particular, se las llama instancia de esa clase.
#
# <b>Nota:</b>
#
# Se dice que los objetos tienen estado y comportamiento, ya que los valores que tengan los atributos de una instancia determinan el estado actual de esa instancia, y los métodos definidos en una clase determinan cómo se va a comportar ese objeto.

# %% [markdown]
# ### Creando una Clase
#
# Para crear una clase se usa la palabra clave ```class```:

# %%
class MyClass:
    x = 31

# %% [markdown]
# ### Creando un Objeto de la Clase
#
# Utilizando la clase creada MyClass podemos crear el objeto de la clase:

# %%
p1 = MyClass()
print(p1.x)
# Out:
# 31

# %% [markdown]
# ### La función __init__()
#
# Los ejemplos anteriores son clases y objetos en su forma más simple, y no son realmente útiles en aplicaciones de la vida real.
#
# Para entender el significado de las clases tenemos que entender la función incorporada __init__().
#
# Todas las clases tienen una función llamada __init __(), que siempre se ejecuta cuando se inicia la clase.
#
# Use la función __init __() para asignar valores a las propiedades del objeto u otras operaciones que sean necesarias cuando se crea el objeto:

# %%
# Cree una clase llamada Person, use la función __init __() para asignar valores para nombre y edad:

class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("John", 36)

print(p1.name)
print(p1.age)
# Out:
# John
# 36

# %% [markdown]
# ### Métodos de Objeto
#
# Los objetos también pueden contener métodos. Los métodos en los objetos son funciones que pertenecen al objeto.
#
# Creemos un método en la clase Person:
#
# Inserte una función que imprima un saludo y ejecútelo en el objeto p1:

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def saludo(self):
    print("Hola mi nombre es " + self.name)

p1 = Person("John", 36)
p1.saludo()
# Out:
# Hola mi nombre es John

# %% [markdown]
# ## 7.1.3 Clases
#
# Una clase minimamente precisa tener un nombre y un método constructor llamado __init__.
#
# La palabra reservada self es una referencia al propio objeto (instancia de la clase).
#
# El parámetro self debe ser el primer parámetro de todas las funciones de la clase.

# %%
#Ejemplo de definición de una clase Dog
class Dog:    
    #Método constructor (inicializa una instancia de Dog)
    def __init__(self, name, age, sound="GUA GUA"):
        self.name = name
        self.age = age
        self.sound = sound
        self.tricks = []    # Crea una nueva lista vacia por cada dog
        self.friend=""

    #Adiciona una habilidad en la lista tricks
    def add_trick(self, trick):
        self.tricks.append(trick)
    
    #Hace al dog ladrar
    def bark(self):
        print(self.sound)
    
    #Redifine al mejor amigo
    def setfriend(self,otherdog):
        self.friend=otherdog
    
    #__str__ es un método especial. Define la representación del objeto como string
    #(el que será exhibido en un print)
    def __str__(self):
        result = "Mi nombre es " + self.name + " y yo tengo " + str(self.age) + " años\n"
        result = result + "Yo ladro haciendo el sonido de " + self.sound + "\n"
        tricklist = ", ".join(self.tricks)
        result = result + "Habilidades: " + tricklist + "\n"
        if self.friend != "":
            result = result + "Mejor amigo: " + self.friend.name + "\n"
        return result

# %%
#Instanciando y usando la clase Dog        
d = Dog('Scooby',4,sound="WOW WOW")
e = Dog('Firulais',7)
d.add_trick('dar vueltitas')
d.add_trick('dar la patita')
d.add_trick('quedarse de pie')
e.add_trick('fingir muerto')
d.setfriend(e)

print(d)
print(e)
# Out:
# Mi nombre es Scooby y yo tengo 4 años
# Yo ladro haciendo el sonido de WOW WOW
# Habilidades: dar vueltitas, dar la patita, quedarse de pie
# Mejor amigo: Firulais
#
# Mi nombre es Firulais y yo tengo 7 años
# Yo ladro haciendo el sonido de GUA GUA
# Habilidades: fingir muerto

# %%
# %%writefile "3.1.3/Persona.py"
# from datetime import date
# from dateutil.relativedelta import relativedelta
#
# class Persona:
#     'Clase que representa al tipo persona'
#     contador = 0
#
#     def __init__(self, nombre, ci, fechaNac, trabajos=None, sueldo=0.0):
#         self.nombre = nombre
#         self.ci = ci
#         self.fechaNac = fechaNac
#         self.trabajos = trabajos if trabajos is not None else []
#         self.sueldo = sueldo
#         Persona.contador += 1
#
#     def dar_aumento_sueldo(self):
#         self.sueldo += self.sueldo * 0.1
#
#     def obtener_edad(self):
#         return relativedelta(date.today(), self.fechaNac).years
#
#     def agregar_trabajo(self, nuevo):
#         self.trabajos.append(nuevo)
# Out:
# Overwriting 3.1.3/Persona.py

# %%
Juan = Persona("Juan", "123456", date(1990, 5, 15), ["Programador"], 5000.0)

# %%
# Usar el método dar_aumento_sueldo
print("Sueldo antes del aumento:", Juan.sueldo)
Juan.dar_aumento_sueldo()
print("Sueldo después del aumento:", Juan.sueldo)
# Out:
# Sueldo antes del aumento: 5000.0
# Sueldo después del aumento: 5500.0

# %%
# Usar el método obtener_edad
print("Edad de la persona:", Juan.obtener_edad())
# Out:
# Edad de la persona: 35

# %%
# Usar el método agregar_trabajo
print("Trabajos antes de agregar:", Juan.trabajos)
Juan.agregar_trabajo("Cientista de Datos")
Juan.agregar_trabajo("Programador de Python")
print("Trabajos después de agregar:", Juan.trabajos)
Juan.dar_aumento_sueldo()
print("Nuevo salario de Juan:", Juan.sueldo)
# Out:
# Trabajos antes de agregar: ['Programador']
# Trabajos después de agregar: ['Programador', 'Cientista de Datos', 'Programador de Python']
# Nuevo salario de Juan: 6050.0

# %%
from datetime import date
from dateutil.relativedelta import relativedelta

class Persona:
    'Clase que representa al tipo persona'
    contador = 0
    
    def __init__(self, nombre, ci, fechaNac, trabajos=None, sueldo=0.0):
        self.nombre = nombre
        self.ci = ci
        self.fechaNac = fechaNac
        self.trabajos = trabajos if trabajos is not None else []
        self.sueldo = sueldo
        Persona.contador += 1
    
    def dar_aumento_sueldo(self):
        self.sueldo += self.sueldo * 0.1
    
    def obtener_edad(self):
        return relativedelta(date.today(), self.fechaNac).years
    
    def agregar_trabajo(self, nuevo):
        self.trabajos.append(nuevo)

# Crear una instancia de Persona
persona1 = Persona("María", "654321", date(1985, 8, 10), ["Ingeniera"], 60000.0)

# Ejemplo de uso de getattr
atributo = "nombre"
valor_del_atributo = getattr(persona1, atributo)
print(f"El valor del atributo '{atributo}' es: {valor_del_atributo}")

atributo_inexistente = "edad"
valor_predeterminado = 0
valor_del_atributo_inexistente = getattr(persona1, atributo_inexistente, valor_predeterminado)
print(f"El valor del atributo '{atributo_inexistente}' es: {valor_del_atributo_inexistente}")
# Out:
# El valor del atributo 'nombre' es: María
# El valor del atributo 'edad' es: 0

# %%
from datetime import date
from dateutil.relativedelta import relativedelta

class Persona:
    'Clase que representa al tipo persona'
    contador = 0
    
    def __init__(self, nombre, ci, fechaNac, trabajos=None, sueldo=0.0):
        self.nombre = nombre
        self.ci = ci
        self.fechaNac = fechaNac
        self.trabajos = trabajos if trabajos is not None else []
        self.sueldo = sueldo
        Persona.contador += 1
    
    def dar_aumento_sueldo(self):
        self.sueldo += self.sueldo * 0.1
    
    def obtener_edad(self):
        return relativedelta(date.today(), self.fechaNac).years
    
    def agregar_trabajo(self, nuevo):
        self.trabajos.append(nuevo)

# Crear una instancia de Persona
persona1 = Persona("Carlos", "987654", date(1995, 3, 20), ["Estudiante"], 40000.0)

# Ejemplo de uso de setattr
atributo = "sueldo"
nuevo_valor = 45000.0
setattr(persona1, atributo, nuevo_valor)
print(f"Nuevo valor del atributo '{atributo}': {persona1.sueldo}")
# Out:
# Nuevo valor del atributo 'sueldo': 45000.0

# %%
from datetime import date
from dateutil.relativedelta import relativedelta

class Persona:
    'Clase que representa al tipo persona'
    contador = 0
    
    def __init__(self, nombre, ci, fechaNac, trabajos=None, sueldo=0.0):
        self.nombre = nombre
        self.ci = ci
        self.fechaNac = fechaNac
        self.trabajos = trabajos if trabajos is not None else []
        self.sueldo = sueldo
        Persona.contador += 1
    
    def dar_aumento_sueldo(self):
        self.sueldo += self.sueldo * 0.1
    
    def obtener_edad(self):
        return relativedelta(date.today(), self.fechaNac).years
    
    def agregar_trabajo(self, nuevo):
        self.trabajos.append(nuevo)

# Crear una instancia de Persona
persona1 = Persona("Ana", "456789", date(2000, 12, 5), ["Recepcionista"], 35000.0)

# Ejemplo de uso de hasattr
atributo_existente = "nombre"
if hasattr(persona1, atributo_existente):
    print(f"La instancia tiene el atributo '{atributo_existente}'")
else:
    print(f"La instancia no tiene el atributo '{atributo_existente}'")

atributo_inexistente = "edad"
if hasattr(persona1, atributo_inexistente):
    print(f"La instancia tiene el atributo '{atributo_inexistente}'")
else:
    print(f"La instancia no tiene el atributo '{atributo_inexistente}'")
# Out:
# La instancia tiene el atributo 'nombre'
# La instancia no tiene el atributo 'edad'

# %%
import sys
from datetime import date

sys.path.append("./3.1.3")
from Persona import Persona # type: ignore

if __name__ == '__main__':
    Fabian = Persona("Fabian Sun", "25345654",
                     date(1990,12,18), ["Economista", "Consultor"], 3500)
    Diana = Persona("Diana He", "89345654",
                    date(1989,6,29))

# %%
# Ejemplo de uso de setattr
atributo = "sueldo"
nuevo_valor = 45000.0
setattr(Fabian, atributo, nuevo_valor)
print(f"Nuevo valor del atributo '{atributo}': {Fabian.sueldo}")
# Out:
# Nuevo valor del atributo 'sueldo': 45000.0

# %% [markdown]
# ---
#
# # 7.2 Ejecutar Programas Python en el Terminal
#
# Para los siguientes códigos, copie y pegue cada uno en un archivo separado. Guardelos con el nombre indicado (File -> New -> Text File, copiar y pegar el código en la pestaña del terminal y renombrar el archivo).
#
# Los programas serán ejecutados en una sesión del terminal (File -> New -> Terminal).

# %% [markdown]
# # Archivo programa1.py

# %%
# %%writefile "3.1.3/programa1.py"
# print ("Hola. Yo soy un programa en Python")
# a = 3
# b = 5
# c=a+b
# print(f"La suma de {a} y {b} es {c}")
# Out:
# Overwriting 3.1.3/programa1.py

# %%
# !python "3.1.3/programa1.py"
# Out:
# Hola. Yo soy un programa en Python
# La suma de 3 y 5 es 8

# %% [markdown]
# # Archivo programa2.py

# %%
# %%writefile "3.1.3/programa2.py"
# import sys
#
# print("Hola. Yo soy un programa en Python")
#
# try:
#     a = int(sys.argv[1])
#     b = int(sys.argv[2])
#     c = a + b
#     print(f"La suma de {a} y {b} es {c}")
# except IndexError:
#     print("Error: Faltan argumentos")
#     print("Uso: python script.py <numero1> <numero2>")
# except ValueError:
#     print("Error: Los argumentos deben ser numeros enteros")
#     print("Uso: python script.py <numero1> <numero2>")
# Out:
# Overwriting 3.1.3/programa2.py

# %%
# !python "3.1.3/programa2.py" 5 8
# Out:
# Hola. Yo soy un programa en Python
# La suma de 5 y 8 es 13

# %%
# !python "3.1.3/programa2.py" 5 8.6
# Out:
# Hola. Yo soy un programa en Python
# Error: Los argumentos deben ser numeros enteros
# Uso: python script.py <numero1> <numero2>

# %% [markdown]
# # Archivo programa3.py

# %%
# %%writefile "3.1.3/programa3.py"
# import sys
# #sys.argv contiene una lista de los argumentos pasados
# numargs = len(sys.argv)
# if numargs != 3:
#     print("Usage: ", sys.argv[0] , "<num1> <num2>")  #ou sys.stderr.write("message")
#     exit(1)  #Cualquier código de salida diferente de zero significa que o programa de erro
# else:
#     a = int(sys.argv[1])
#     b = int(sys.argv[2])
#     c = a+b
#     print(f"La suma de {a} y {b} es {c}")
# Out:
# Overwriting 3.1.3/programa3.py

# %%
# !python "3.1.3/programa3.py" 2 7
# Out:
# La suma de 2 y 7 es 9

# %% [markdown]
# # 7.3 Estrutura de un módulo

# %%
#!/usr/bin/env/python3
import sys

def funcao1(a,b,c):
    #bloque del codigo
    return qualquercoisa

def funcao2(a,b,c):
    #bloque del codigo
    return qualquercoisa

def main():
    #código principal del programa
#Si el programa fuera ejecutado directamente, la variable implícita __name__ == ‘__main__’
#Si fuera importado, __name__ será diferente de __main__ y el método main() no será ejecutado

if __name__ == '__main__':
    main()
# Out:
#   Cell In[3], line 17
#     if __name__ == '__main__':
#     ^
# IndentationError: expected an indented block after function definition on line 12

# %%
import sys
from math import cos, sin  # Cambiado sen -> sin

sys.path.append("./3.1.3")
from Persona import Persona # type: ignore

#### codigo

# %% [markdown]
# ### Ejercicio 1:
#
# Cree un módulo imc.py con su rutina de cálculo de imc (llámelo calc_imc). Este programa debe implementarse como un módulo que puede ejecutarse directamente o simplemente importarse. Los valores de peso y altura deben leerse desde la línea de comando y el programa debe probar si ha recibido exactamente dos argumentos.

# %%
# %%writefile "3.1.3/imc.py"
# # ============================================
# # imc.py
# # ============================================
# # Lic. Ilian Joseph Felipez Vaca
# # ============================================
#
# import sys
#
# def calc_imc(peso: float, altura: float) -> float:
#     return peso / (altura ** 2)
#
# def es_numero_valido(valor: str) -> bool:
#     try:
#         num = float(valor)
#         return num > 0
#     except ValueError:
#         return False
#
# def validar_argumentos():
#     if len(sys.argv) != 3:
#         print("Error: Se requieren exactamente 2 argumentos")
#         print("Uso: python imc.py <peso_kg> <altura_m>")
#         print("\t<peso_kg> : Numero positivo (ej: 70.5)")
#         print("\t<altura_m> : Numero positivo (ej: 1.75)")
#         sys.exit(1)
#
#     peso_str = sys.argv[1]
#     altura_str = sys.argv[2]
#
#     if not es_numero_valido(peso_str):
#         print(f"Error: '{peso_str}' no es un peso valido")
#         print("El peso debe ser un numero positivo (ej: 70, 70.5)")
#         sys.exit(1)
#
#     if not es_numero_valido(altura_str):
#         print(f"Error: '{altura_str}' no es una altura valida")
#         print("La altura debe ser un numero positivo (ej: 1.75, 1.80)")
#         sys.exit(1)
#
#     return float(peso_str), float(altura_str)
#
# # ========== ENTRY POINT ==========
# if __name__ == "__main__":
#     peso, altura = validar_argumentos()
#     imc = calc_imc(peso, altura)
#     print(f"\tPeso: {peso:.2f} kg")
#     print(f"\tAltura: {altura:.2f} m")
#     print(f"\tIMC: {imc:.2f}")
# Out:
# Overwriting 3.1.3/imc.py

# %%
# !python "3.1.3/imc.py" 70 1.75
# Out:
# 	Peso: 70.00 kg
# 	Altura: 1.75 m
# 	IMC: 22.86

# %% [markdown]
# ### Ejercicio 2:
#
# Escriba un programa4.py que use la función calc_imc del módulo imc.py (importe el módulo imc con una de las siguiente alternativas).
#
# Tres alternativas que deberán cambiar la forma de la función calc_imc:
#
# ```python
# import imc
#
# #llamada
# imc.calc_imc(altura,peso)
# ```
# ### o
# ```python
# import imc as i
#
# #llamada
# i.calc_imc(altura,peso)
# ```
# ### o
# ```python
# from imc import calc_imc
#
# #llama
# calc_imc(altura,peso)
# ```
#
# ###Template para su programa4.py
# ```python
# #!/usr/bin/env python3
# import sys
# import imc
# #import imc as i
# #from imc import calc_imc
#
#
# def main():
#     #código principal del programa
#     #Si el programa fuera ejecutado diretacmente, la variable implícita __name__ == ‘__main__’
#     #Si fuera importado, __name__ será diferente de __main__ y el método main() no será ejecutado
#
# #Su código comienza a ser ejecutado aqui:
# if __name__ == '__main__':
#     main()
# ```

# %%
# %%writefile "3.1.3/programa4.py"
# # ============================================
# # programa4.py
# # ============================================
# # Lic. Ilian Joseph Felipez Vaca
# # ============================================
#
# import sys
# import imc
#
# def clasificar_imc(imc: float) -> str:
#     if imc < 18.5:
#         return "Bajo peso"
#     elif imc < 25:
#         return "Peso normal"
#     elif imc < 30:
#         return "Sobrepeso"
#     elif imc < 35:
#         return "Obesidad grado I"
#     elif imc < 40:
#         return "Obesidad grado II"
#     else:
#         return "Obesidad grado III"
#
# def main():
#     if len(sys.argv) != 3:
#         print("Error: Se requieren exactamente 2 argumentos")
#         print("Uso: python programa4.py <peso_kg> <altura_m>")
#         sys.exit(1)
#
#     try:
#         peso = float(sys.argv[1])
#         altura = float(sys.argv[2])
#
#         if peso <= 0 or altura <= 0:
#             print("Error: Peso y altura deben ser valores positivos")
#             sys.exit(1)
#
#         imc_resultado = imc.calc_imc(peso, altura)
#         clasificacion = clasificar_imc(imc_resultado)
#
#         print("\t=================================")
#         print("\t       CALCULADORA DE IMC")
#         print("\t=================================")
#         print(f"\tPeso: {peso:.2f} kg")
#         print(f"\tAltura: {altura:.2f} m")
#         print(f"\tIMC: {imc_resultado:.2f}")
#         print(f"\tClasificacion: {clasificacion}")
#         print("\t=================================")
#
#     except ValueError:
#         print("Error: Los argumentos deben ser numeros")
#         print("Uso: python programa4.py <peso_kg> <altura_m>")
#         sys.exit(1)
#
# # ========== ENTRY POINT ==========
# if __name__ == '__main__':
#     main()
# Out:
# Overwriting 3.1.3/programa4.py

# %%
# !python "3.1.3/programa4.py" 70 1.75
# Out:
# ...
# 	       CALCULADORA DE IMC
# ...
# 	Peso: 70.00 kg
# 	Altura: 1.75 m
# 	IMC: 22.86
# 	Clasificacion: Peso normal
# ...

# %% [markdown]
# <div style="display: inline-block; width: 480px; background: linear-gradient(145deg, #1a1a2e, #16213e); padding: 22px 28px; border-radius: 18px; text-align: center; border: 1px solid rgba(255,255,255,0.15); box-shadow: 0 5px 15px rgba(0,0,0,0.2);">
#     <div style="font-size: 42px; margin-bottom: 5px;">🎯🐍</div>
#     <p style="color: white; font-weight: bold; font-size: 20px; margin: 5px 0; font-family: 'Segoe UI', Arial, sans-serif;">Notebook Finalizado</p>
#     <p style="color: #facc15; font-size: 18px; font-weight: bold; margin: 8px 0; font-family: 'Segoe UI', Arial, sans-serif;">Ilian Joseph Felipez Vaca</p>
#     <p style="color: #aaaacc; font-size: 13px; margin: 5px 0 10px 0; font-family: 'Segoe UI', Arial, sans-serif;">Licenciado en Ingeniería de Sistemas Informáticos</p>
#     <div style="margin-top: 10px; padding-top: 10px; border-top: 1px solid rgba(255,255,255,0.1);">
#         <p style="margin: 5px 0; font-size: 12px;"><a href="https://github.com/ElTioCrack" target="_blank" style="color: #88ddff; text-decoration: none;">github.com/ElTioCrack</a></p>
#         <p style="margin: 5px 0; font-size: 12px;"><a href="https://www.linkedin.com/in/ilian-joseph-felipez-vaca/?locale=en" target="_blank" style="color: #88ddff; text-decoration: none;">linkedin.com/in/ilian-joseph-felipez-vaca</a></p>
#     </div>
# </div>
